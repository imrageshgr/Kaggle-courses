# %% [markdown]
# # Employee Expense Reimbursement Calculator

# %%
employee_name = input("Enter employee name: ")
employee_id = input("Enter employee ID: ")
travel_days = int(input("Enter number of travel days: "))
food_expenses = float(input("Enter food expenses: "))
transportation_expenses = float(input("Enter transportation expenses: "))
hotel_expense = float(input("Enter hotel expenses: "))
other_expense = float(input("Enter other expenses: "))
