# %% [markdown]
# # Printing

# %%
print("your message") 
# This is a built-in function used to display output to the console, terminal, screen, and IDE.
# Out:
# your message

# %%
print("I am Ragesh G R")
print("Let's learn python programming from scratch at kaggle.com")
# Out:
# I am Ragesh G R
# Let's learn python programming from scratch at kaggle.com

# %% [markdown]
# # Arithmetic

# %%
# Addition symbol is: +
print(5 + 8)
# Out:
# 13

# %%
# Subtraction symbol is: -
print(5 - 8)
# Out:
# -3

# %%
# Multiplication symbol is: *
print(5 * 8)
# Out:
# 40

# %%
# Division symbol is: / 
print(5 / 8)
# Out:
# 0.625

# %%
# Exponentiation symbol is: **
print(5 ** 2)
# Like 5 square of 2 or 5 power of 2
# Out:
# 25

# %%
# In python, solve this equation by using PEMDAS rule (Parentheses, Exponents, Multiplication and Division, Addition and Subtraction) 
print(((1 + 3) * (9 - 2) / 2) ** 2)
# Step by step solution for above equation
#((1 + 3) * (9 - 2) / 2) ** 2
#((4) * (7) / 2) ** 2
#((28) / 2) ** 2
#(14) ** 2
#196
# Out:
# 196.0

# %% [markdown]
# # Comments

# %%
# This line of code or text not execute in python programming because it is a comment line.
# In python, we can write comments by using # symbol.
# Help for programmers to understand the code and also help for future reference.

print("Read the above comments to understand")
# Out:
# Read the above comments to understand

# %% [markdown]
# # Variables

# %%
variable_name = "Value"
# This is simple variable create for unserstand

# %%
print(variable_name)
# Called the variable name to display the value stored in variable
# Out:
# Value

# %%
# Creating the variable names have the following rules:
# 1. Variable names can only contain letters, numbers, and underscores.
# 2. Variable names must start with a letter or an underscore.
# 3. Variable names are case-sensitive (age, Age, and AGE are three different variables).
# 4. Variable names cannot be a reserved word (like print, if, else, while, etc.) in Python.

_user_name = "Test_case with underscore"
user_name = "Test_case without underscore"
user_name1 = "Test_case with number"
UserName = "Test_case with camel case"

print(_user_name)
print(user_name)
print(user_name1)
print(UserName)
# Out:
# Test_case with underscore
# Test_case without underscore
# Test_case with number
# Test_case with camel case
